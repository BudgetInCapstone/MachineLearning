# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn import datasets
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
#from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# # load the rating data
# from google.colab import drive
# drive.mount('/content/drive')
# dataset = pd.read_csv('/content/drive/MyDrive/fooddata.csv')
# dataset.head()

# LOAD MANUAL
from google.colab import files
Train = files.upload()
# Out:
#      <input type="file" id="files-d7ceee4d-777f-4132-a684-5182748a4c50" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d7ceee4d-777f-4132-a684-5182748a4c50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Train = pd.read_csv('dataset_rest_V1.csv')
Train = Train[['coordinate']]
Train
# Out:
#                                    coordinate
# 0      -6.237889691551521, 106.71691122414389
# 1      -6.237889691551521, 106.71691122414389
# 2      -6.237889691551521, 106.71691122414389
# 3      -6.237889691551521, 106.71691122414389
# 4      -6.237889691551521, 106.71691122414389
# ...                                       ...
# 39591  -7.442382326294656, 112.72844026387789
# 39592  -7.442382326294656, 112.72844026387789
# 39593  -7.442382326294656, 112.72844026387789
# 39594  -7.442382326294656, 112.72844026387789
# 39595  -7.442382326294656, 112.72844026387789
#
# [39596 rows x 1 columns]

# %%
Train[['xtrain', 'ytrain']] = Train['coordinate'].str.split(", ", expand = True)
Train.drop(['coordinate'], axis=1, inplace=True)
Train
# Out:
#                    xtrain              ytrain
# 0      -6.237889691551521  106.71691122414389
# 1      -6.237889691551521  106.71691122414389
# 2      -6.237889691551521  106.71691122414389
# 3      -6.237889691551521  106.71691122414389
# 4      -6.237889691551521  106.71691122414389
# ...                   ...                 ...
# 39591  -7.442382326294656  112.72844026387789
# 39592  -7.442382326294656  112.72844026387789
# 39593  -7.442382326294656  112.72844026387789
# 39594  -7.442382326294656  112.72844026387789
# 39595  -7.442382326294656  112.72844026387789
#
# [39596 rows x 2 columns]

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=20)

# %% [markdown]
# Ini kodingan asal

# %% [markdown]
# ini kodingan ada tf nya gatau beenr apa ga

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

# Extracting Independent and dependent Variable
xtrain = Train.iloc[0].values
ytrain = Train.iloc[1].values


# Splitting the dataset into training and test set
x_train, x_test, y_train, y_test = train_test_split(xtrain, ytrain, test_size=0.25, random_state=0)

# %%
# Feature Scaling
scaler = StandardScaler()

x_train = np.reshape(x_train, (-1,))
x_train = np.reshape(x_test, (-1,))

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-07e166766f66> in <cell line: 7>()
#       5 x_train = np.reshape(x_test, (-1,))
#       6
# ----> 7 x_train = scaler.fit_transform(x_train)
#       8 x_test = scaler.transform(x_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from sklearn.metrics import confusion_matrix


# # Extracting Independent and dependent Variable
# x = Train.iloc[:, [2,3]].values
# y = Train.iloc[:, 4].values

# # Splitting the dataset into training and test set
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# Feature Scaling
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# Define the KNN model using TensorFlow
knn_model = tf.keras.Sequential([

    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
knn_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

# Train the KNN model
knn_model.fit(x_train, y_train, epochs=10, batch_size=32)

# Predicting the test set result
y_pred = knn_model.predict_classes(x_test)

# Creating the Confusion matrix
cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8e0e00cc33df> in <cell line: 7>()
#       5
#       6 # Extracting Independent and dependent Variable
# ----> 7 x = data_set.iloc[:, [2,3]].values
#       8 y = data_set.iloc[:, 4].values
#       9
#
# NameError: name 'data_set' is not defined

# %%
#Visulaizing the trianing set result
from matplotlib.colors import ListedColormap
x_set, y_set = x_train, y_train
x1, x2 = nm.meshgrid(nm.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step  =0.01),
nm.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01))
mtp.contourf(x1, x2, classifier.predict(nm.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),
alpha = 0.75, cmap = ListedColormap(('red','green' )))
mtp.xlim(x1.min(), x1.max())
mtp.ylim(x2.min(), x2.max())
for i, j in enumerate(nm.unique(y_set)):
    mtp.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],
        c = ListedColormap(('red', 'green'))(i), label = j)
mtp.title('K-NN Algorithm (Training set)')
mtp.xlabel('Age')
mtp.ylabel('Estimated Salary')
mtp.legend()
mtp.show()

# %%
#Visualizing the test set result
from matplotlib.colors import ListedColormap
x_set, y_set = x_test, y_test
x1, x2 = nm.meshgrid(nm.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step  =0.01),
nm.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01))
mtp.contourf(x1, x2, classifier.predict(nm.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),
alpha = 0.75, cmap = ListedColormap(('red','green' )))
mtp.xlim(x1.min(), x1.max())
mtp.ylim(x2.min(), x2.max())
for i, j in enumerate(nm.unique(y_set)):
    mtp.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],
        c = ListedColormap(('red', 'green'))(i), label = j)
mtp.title('K-NN algorithm(Test set)')
mtp.xlabel('Age')
mtp.ylabel('Estimated Salary')
mtp.legend()
mtp.show()
